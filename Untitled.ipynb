# %%
import requests
import pandas as pd
import time
from bs4 import BeautifulSoup as soup
url = "https://winemag.com/region/oregon/"

# %%
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = { "executable_path": ChromeDriverManager().install()}
browser = Browser("chrome", **executable_path, headless=False)

# %%
browser.visit(url)

html = browser.html
soup = soup(html, "html.parser")

# %%
data = soup.find_all("section", class_="wine-reviews")
for d in data: 
    time.sleep(5)
    title = d.find_all("h3", class_="title")
    location = d.find_all("span", class_="appellation")
    reviews = d.find_all("div", class_="excerpt")
    points = d.find_all('span', class_= "rating")
    prices = d.find_all('span', class_= "price")
    
new_title = []
new_location = []
new_reviews = []
for t in title:
    new_title.append(t.text)

for l in location: 
    new_location.append(l.text)
    
for r in reviews: 
    new_reviews.append(r.text)
    
# Remove duplicates
new_location = list(new_location)
new_title = list(set(new_title))
new_reviews = list(set(new_reviews))

# %%
pd.DataFrame(data={"title": new_title, "location": new_location[::2], "reviews": new_reviews,} )
# Out:
#                                                 title           location  \
# 0   Rex Hill 2019 Antiquum Vineyard Pinot Noir (Wi...  Willamette Valley
# 1   Bryn Mawr Vineyards 2019 Estate Chardonnay (Eo...       Oregon Other
# 2   Rex Hill 2019 Shea Vineyard Pinot Noir (Yamhil...       Oregon Other
# 3   Cayuse 2019 Wallah Wallah Special #13 Syrah (W...       Oregon Other
# 4   Flâneur 2019 Cuvée Constantin Pinot Noir (Will...  Willamette Valley
# 5   Flâneur 2019 La Belle Promenade Vineyard Pinot...       Oregon Other
# 6        SuNu 2019 Saffron Fields Pinot Noir (Oregon)       Oregon Other
# 7   WillaKenzie Estate 2019 Aliette Pinot Noir (Ya...  Willamette Valley
# 8      SuNu 2019 Matteri Vineyard Pinot Noir (Oregon)  Willamette Valley
# 9   SuNu 2019 Shea East Hill Heritage Clones Pinot...  Willamette Valley
# 10  Elizabeth Chambers 2019 Temperance Hill Vineya...  Willamette Valley
# 11  The Eyrie Vineyards 2019 Estate Pinot Noir (Du...  Willamette Valley
# 12  Abacela 2019 Estate Produced Grenache (Umpqua ...  Willamette Valley
# 13  Ermisch 2020 Ribbon Ridge Single Vineyard Pino...  Willamette Valley
# 14  Abacela 2017 Estate Produced South East Block ...  Willamette Valley
# 15           SuNu 2019 Lazy River Pinot Noir (Oregon)  Willamette Valley
# 16              Force Majeure 2019 SJR Vineyard Syrah       Oregon Other
# 17  Flâneur 2019 Espirit de Corps Pinot Noir (Ribb...    Southern Oregon
# 18  Alexana 2019 Fennwood Vineyard Pinot Noir (Yam...    Southern Oregon
# 19     Big Table Farm 2019 Funk Estate Vineyard Syrah       Oregon Other
#
#                                               reviews
# 0   This is consistently SuNu's richest offering, ...
# 1   This wine shows reduction out of the gate that...
# 2   This appellation is known for its earthy, savo...
# 3   The aromas of this wine, coming from a site in...
# 4   Aromas of dark, crushed berry, wood spice and ...
# 5   The aromas of this wine, only made in magnum, ...
# 6   This vineyard at the edge of the Rocks Distric...
# 7   All the fruit for this wine comes from Flaneri...
# 8   This is all Dijon 115 Clone from this Yamhill-...
# 9   White pepper aromas jump out of the glass, fol...
# 10  Coming from a vineyard on Jory and fractured b...
# 11  Aromas of dried flower, cherry and herb are fo...
# 12  Cherry, licorice, Red Vines candy, flower and ...
# 13  Aromas of dark cherry, cola, coffee and barrel...
# 14  This wine shows some reduction initially. Beyo...
# 15  The aromas show reduction on the first whiff. ...
# 16  Aged in a combination of new and used French o...
# 17  Just over two-thirds of the fruit comes from L...
# 18  The aromas boast hyper-appealing notes of nect...
# 19  The aromas intoxicate, with notes of black tea...
