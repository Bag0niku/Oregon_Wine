# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
from geopy.geocoders import Nominatim
import geopy
import folium
import gmaps
import requests
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

table_OVGPS = pd.read_html('file:///Users/darrin/Desktop/Class/Oregon_Wine/vineyard_project/resources/google_vineyards.csv.html')
#table_OVDetail = pd.read_html('file:///Users/darrin/Desktop/Class/Oregon_Wine/vineyard_project/resources/cleaned_google_vineyard_details.html')
#table_OVReviews = pd.read_html('file:///Users/darrin/Desktop/Class/Oregon_Wine/vineyard_project/resources/cleaned_google_vineyard_reviews.csv.html')
#table_OVWine = pd.read_html ('file:///Users/darrin/Desktop/Class/Oregon_Wine/vineyard_project/resources/clean_wine_df_csv.html')

# %%
df = table_OVGPS[0]
df.head()
#print(df.index)
#print('Row count is:', len(df.index))
# Out:
#    Unnamed: 0                     place_id                    name  \
# 0         NaN  ChIJY_YvLqs_lVQRQ1JGKPCC-qA            Beaux Frères
# 1         NaN  ChIJb07wO0IUlVQRpT7hr_IPjrc           Ruby Vineyard
# 2         NaN  ChIJ0837TqdBlVQR8w_X_SPvVx4    Dobbes Family Estate
# 3         NaN  ChIJ22vW2sjFolQRohtq-192_d0      FireThorn Vineyard
# 4         NaN  ChIJZS1JIJ05xFQRBC3XPLxiy0o  Freed Estate Vineyards
#
#         status           phone  \
# 0  OPERATIONAL  (503) 537-1137
# 1  OPERATIONAL  (503) 628-7829
# 2  OPERATIONAL  (503) 538-1141
# 3  OPERATIONAL  (206) 391-6709
# 4  OPERATIONAL  (808) 551-9998
#
#                                    formatted_address  \
# 0  15155 NE North Valley Rd, Newberg, OR, 97132, USA
# 1       30088 SW Egger Rd, Hillsboro, OR, 97123, USA
# 2              240 SE 5th St, Dundee, OR, 97115, USA
# 3                75049 Snow Rd, Echo, OR, 97826, USA
# 4             430 Hooten Rd, Winston, OR, 97496, USA
#
#                                            gmaps_url  \
# 0  https://maps.google.com/?cid=11599727758225592899
# 1  https://maps.google.com/?cid=13226526690641002149
# 2   https://maps.google.com/?cid=2186479081973288947
# 3  https://maps.google.com/?cid=15996071606101875618
# 4   https://maps.google.com/?cid=5389509939693038852
#
#                                      website  rating  totatl_reviews  ...  \
# 0                http://www.beauxfreres.com/     4.9            57.0  ...
# 1               http://www.rubyvineyard.com/     4.7            83.0  ...
# 2             http://dobbesfamilyestate.com/     4.7            94.0  ...
# 3  http://www.firethornvineyard.com/contact/     5.0             1.0  ...
# 4          http://www.freedestatewinery.com/     5.0            33.0  ...
#
#   country empty                   brand brand_id central_lat  central_lon  \
# 0     USA   NaN            Beaux Frères        0   45.347624  -123.093657
# 1     USA   NaN           Ruby Vineyard        1   45.400388  -122.986932
# 2     USA   NaN    Dobbes Family Estate        2   45.279530  -123.007842
# 3     USA   NaN      FireThorn Vineyard        3   45.721947  -119.191804
# 4     USA   NaN  Freed Estate Vineyards        4   43.115009  -123.393550
#
#   northeast_lat  northeast_lon  southwest_lat  southwest_lon
# 0     45.348952    -123.092368      45.346254    -123.095066
# 1     45.401937    -122.985077      45.399239    -122.987775
# 2     45.280645    -123.006711      45.277947    -123.009409
# 3     45.723296    -119.190455      45.720598    -119.193153
# 4     43.116739    -123.392243      43.114041    -123.394941
#
# [5 rows x 24 columns]

# %%
df = df.drop(['Unnamed: 0', 'place_id', 'status', 'gmaps_url', 'rating','totatl_reviews',
              'country', 'empty', 'brand', 'street_address', 'city', 'province', 'zipcode',
              'northeast_lat', 'northeast_lon', 'southwest_lat', 'southwest_lon'], axis = 1)
print (df)
# Out:
#                                             name           phone  \
# 0                                   Beaux Frères  (503) 537-1137
# 1                                  Ruby Vineyard  (503) 628-7829
# 2                           Dobbes Family Estate  (503) 538-1141
# 3                             FireThorn Vineyard  (206) 391-6709
# 4                         Freed Estate Vineyards  (808) 551-9998
# ..                                           ...             ...
# 621                       Legacy Estate Vineyard  (503) 362-1546
# 622                            Melrose Vineyards  (541) 672-6080
# 623  Lachini Winery & Tasting Bar ~ Tualatin, OR  (503) 864-4553
# 624                                Schultz Wines  (541) 414-8448
# 625                          King's Raven Winery  (503) 505-6873
#
#                                      formatted_address  \
# 0    15155 NE North Valley Rd, Newberg, OR, 97132, USA
# 1         30088 SW Egger Rd, Hillsboro, OR, 97123, USA
# 2                240 SE 5th St, Dundee, OR, 97115, USA
# 3                  75049 Snow Rd, Echo, OR, 97826, USA
# 4               430 Hooten Rd, Winston, OR, 97496, USA
# ..                                                 ...
# 621           1600 Oak Grove Rd, Salem, OR, 97304, USA
# 622            885 Melqua Rd, Roseburg, OR, 97471, USA
# 623       19930 SW 112th Ave, Tualatin, OR, 97062, USA
# 624   755 Slagle Creek Rd, Grants Pass, OR, 97527, USA
# 625    11603 S New Era Rd, Oregon City, OR, 97045, USA
#
#                                                website  brand_id  central_lat  \
# 0                          http://www.beauxfreres.com/         0    45.347624
# 1                         http://www.rubyvineyard.com/         1    45.400388
# 2                       http://dobbesfamilyestate.com/         2    45.279530
# 3            http://www.firethornvineyard.com/contact/         3    45.721947
# 4                    http://www.freedestatewinery.com/         4    43.115009
# ..                                                 ...       ...          ...
# 621  https://www.exploretock.com/legacyestatevineya...       511    44.957085
# 622  http://www.melrosevineyards.com/?utm_source=go...       512    43.257695
# 623                  https://www.lachinivineyards.com/       241    45.375478
# 624                       http://www.schultzwines.com/       513    42.302082
# 625                         http://kingsravenwine.com/       514    45.296631
#
#      central_lon
# 0    -123.093657
# 1    -122.986932
# 2    -123.007842
# 3    -119.191804
# 4    -123.393550
# ..           ...
# 621  -123.152169
# 622  -123.455390
# 623  -122.793244
# 624  -123.205101
# 625  -122.627562
#
# [626 rows x 7 columns]

# %%
df.to_csv('Winery_Location_GPS', encoding='utf-8')

# %%
df = pd.read_csv('Winery_Location_GPS')
df.head(10)
# Out:
#    Unnamed: 0                                       name           phone  \
# 0           0                               Beaux Frères  (503) 537-1137
# 1           1                              Ruby Vineyard  (503) 628-7829
# 2           2                       Dobbes Family Estate  (503) 538-1141
# 3           3                         FireThorn Vineyard  (206) 391-6709
# 4           4                     Freed Estate Vineyards  (808) 551-9998
# 5           5                Willamette Valley Vineyards  (503) 588-9463
# 6           6                      Cherry Grove Vineyard  (503) 985-3513
# 7           7                      Oswego Hills Vineyard  (503) 655-2599
# 8           8                             The Pines 1852  (541) 993-8301
# 9           9  Ransom Wine Co. & Distillery Tasting Room  (503) 472-2493
#
#                                    formatted_address  \
# 0  15155 NE North Valley Rd, Newberg, OR, 97132, USA
# 1       30088 SW Egger Rd, Hillsboro, OR, 97123, USA
# 2              240 SE 5th St, Dundee, OR, 97115, USA
# 3                75049 Snow Rd, Echo, OR, 97826, USA
# 4             430 Hooten Rd, Winston, OR, 97496, USA
# 5      8800 Enchanted Way SE, Turner, OR, 97392, USA
# 6  49969 SW Patton Valley Rd, Gaston, OR, 97119, USA
# 7         450 Rosemont Rd, West Linn, OR, 97068, USA
# 8             415 Oak St, Hood River, OR, 97031, USA
# 9               23145 OR-99W, Dundee, OR, 97115, USA
#
#                                      website  brand_id  central_latitude  \
# 0                http://www.beauxfreres.com/         0         45.347624
# 1               http://www.rubyvineyard.com/         1         45.400388
# 2             http://dobbesfamilyestate.com/         2         45.279530
# 3  http://www.firethornvineyard.com/contact/         3         45.721947
# 4          http://www.freedestatewinery.com/         4         43.115009
# 5                        http://www.wvv.com/         5         44.827782
# 6       https://www.cherrygrovevineyard.com/         6         45.444115
# 7               https://www.oswegohills.com/         7         45.387026
# 8           http://www.thepinesvineyard.com/         8         45.708646
# 9              http://www.ransomspirits.com/         9         45.290464
#
#    central_longitude
# 0        -123.093657
# 1        -122.986932
# 2        -123.007842
# 3        -119.191804
# 4        -123.393550
# 5        -123.012355
# 6        -123.194118
# 7        -122.674398
# 8        -121.515193
# 9        -122.999178

# %%
mapa = folium.Map(location=(45.523064, -122.676483), zoom_start=6)
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36ef16eb784c643bd588534dc6f40c3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36ef16eb784c643bd588534dc6f40c3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_36ef16eb784c643bd588534dc6f40c3d = L.map(
#                 &quot;map_36ef16eb784c643bd588534dc6f40c3d&quot;,
#                 {
#                     center: [45.523064, -122.676483],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0b990f29206fe0a91c1a109fc97e042 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36ef16eb784c643bd588534dc6f40c3d);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[df.central_latitude.mean(), 
                           df.central_longitude.mean(),
                           ], zoom_start=8, control_scale=True)

# %%
for index, row in df.iterrows():
    folium.Marker(location=(row['central_latitude'],row['central_longitude'])).add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4740fad8771aa61660aa5e723f37a50c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4740fad8771aa61660aa5e723f37a50c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4740fad8771aa61660aa5e723f37a50c = L.map(
#                 &quot;map_4740fad8771aa61660aa5e723f37a50c&quot;,
#                 {
#                     center: [45.01117949121406, -122.31173527795525],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#
#
#
#             var tile_layer_8c1f71d471b16afbd80a3835fe6ddec5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_ca4d5401cabebe81d839f9aa1ba91bde = L.marker(
#                 [45.34762389999999, -123.0936571],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_6e6eed0cd4c6f8671c43fcbb526ed746 = L.marker(
#                 [45.40038819999999, -122.9869325],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_375f5289c0cbdb296bb909615071f312 = L.marker(
#                 [45.2795302, -123.0078417],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_a18170795e6b3d0442fceedc42d36f88 = L.marker(
#                 [45.72194710000001, -119.1918038],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_c00257ac9bc19eb5055813de1a15de8d = L.marker(
#                 [43.115009, -123.39355],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_f870f31ba4b7e491a4de87ed8daa8509 = L.marker(
#                 [44.82778169999999, -123.0123551],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_8b406e4339340f34433cc6b674db570d = L.marker(
#                 [45.4441154, -123.1941181],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_02307ca075bfb231db12f674b19510a4 = L.marker(
#                 [45.3870262, -122.674398],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_7ef2367048aa7b5bf13dae93ec89885d = L.marker(
#                 [45.7086461, -121.5151932],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_84b1153ca627c82b46affa445f13b745 = L.marker(
#                 [45.2904641, -122.999178],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_37d5825f9e682a3e139d6f0c9fe72ef2 = L.marker(
#                 [44.797013, -123.036836],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_a3d4ee1feb171b8bea3aba4fed5180b3 = L.marker(
#                 [44.058572, -121.31398],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_9f36ed9258d55b8f94138e08ff0cfd76 = L.marker(
#                 [44.313722, -123.324039],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_34d01146273761fafbb11ad94d0cd129 = L.marker(
#                 [44.0538141, -123.092401],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_3836947d1ff58071b7a688c6096bd6c7 = L.marker(
#                 [43.6363158, -123.5658985],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_46f8041510750792bfe865a6a513fae0 = L.marker(
#                 [46.00699960000001, -118.3815932],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_efd175d33e9a82563e2291f556ad35d4 = L.marker(
#                 [45.7090566, -121.512944],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_cd399a1bbdebffb8a64975b4c3a4f614 = L.marker(
#                 [46.0694676, -118.3359568],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_bf8dfc9128736bf91353693990087972 = L.marker(
#                 [45.48715840000001, -122.6476872],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker_dd60a648f06c8994376403b69ad401de = L.marker(
#                 [45.5082821, -122.6590832],
#                 {}
#             ).addTo(map_4740fad8771aa61660aa5e723f37a50c);
#
#
#             var marker

# %%
#for row in df.iterrows():
  #  row_values = row[1]
  #  location = [row_values['central_latitude'], row_values['central_longitude']]
   # popup = popup = '<strong>' + row_values['name'] + '<strong>'
   # marker = folium.Marker(location = location, popup = popup)
  #  marker.add_to(map)
    
#display(map)

# %%
html = pd.read_html('file:///Users/darrin/Desktop/Class/Oregon_Wine/vineyard_project/resources/popup.html')

# %%
map = folium.Map(location=(45.523064, -122.676483), zoom_start=6)

def popup_html(i):
    
    winery_name = df['name'].iloc[i] 
    winery_url = df['website'].iloc[i]
    winery_address =df['formatted_address'].iloc[i] 
    winery_phone = df['phone'].iloc[i]
    color = "Blue"
    left_col_color = "#19a7bd"
    right_col_color = "#f2f0d3"

    
    html = """<!DOCTYPE html>
<html>

<head>

<h4 style = "margin-bottom:10" ; width = "200px">{}</h4>""".format(winery_name) + """"
</head>
    <table style = "height: 126px; width: 350px;">
<tbody>

<tr>

<td style ="background-color: """ + left_col_color + """ ;"><span style = "color: #ffffff;">Winery URL</span></td>
<td style ="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(winery_url) + """
</tr>
<tr>
<td style ="background-color: """+ left_col_color +""";"><span style = "color: #ffffff;">Address</span></td>
<td style ="width: 150px;background-color: """ + right_col_color +""";">{}</td>""".format(winery_address) + """
</tr>
<tr>
<td style ="background-color: """ + left_col_color + """;"><span style ="color: #ffffff;">Winery phone</span></td>
<td style ="width: 150px;background-color: """ + right_col_color +""" ;">{}</td>""".format(winery_phone) + """
</tr>
</tbody>
</table>
</html>
"""
    return html 

from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster()


for i in range(0,len(df)):
    winery_name = df['name'].iloc[i]
    color = 'blue'
    html = popup_html(i)
    popup = folium.Popup(folium.Html(html, script=True), max_width=500)
    folium.Marker([df['central_latitude'].iloc[i],df['central_longitude'].iloc[i]],
                  popup=popup,icon=folium.Icon(color='blue', icon='name', prefix='fa')).add_to(marker_cluster)    
marker_cluster.add_to(map) 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c6a4cd6d3002aa6a187a3c382bcac02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c6a4cd6d3002aa6a187a3c382bcac02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4c6a4cd6d3002aa6a187a3c382bcac02 = L.map(
#                 &quot;map_4c6a4cd6d3002aa6a187a3c382bcac02&quot;,
#                 {
#                     center: [45.523064, -122.676483],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eab845b74a433c1957aaa3a148812025 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4c6a4cd6d3002aa6a187a3c382bcac02);
#
#
#             var marker_cluster_aab315a71581cec800147ede2bce15a2 = L.markerClusterGroup(
#                 {}
#             );
#             map_4c6a4cd6d3002aa6a187a3c382bcac02.addLayer(marker_cluster_aab315a71581cec800147ede2bce15a2);
#
#
#             var marker_46b8cf33d03e81ebb9e439fb117db0c7 = L.marker(
#                 [45.34762389999999, -123.0936571],
#                 {}
#             ).addTo(marker_cluster_aab315a71581cec800147ede2bce15a2);
#
#
#             var icon_91d0d63ad8dfb32716ae4cfa06fa67c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;name&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_46b8cf33d03e81ebb9e439fb117db0c7.setIcon(icon_91d0d63ad8dfb32716ae4cfa06fa67c9);
#
#
#         var popup_8532ff6b42c9f445833a29212f9ec035 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_9848807d3ba9d69318532341f43b85b1 = $(`&lt;div id=&quot;html_9848807d3ba9d69318532341f43b85b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt; &lt;html&gt;  &lt;head&gt;  &lt;h4 style = &quot;margin-bottom:10&quot; ; width = &quot;200px&quot;&gt;Beaux Frères&lt;/h4&gt;&quot; &lt;/head&gt;     &lt;table style = &quot;height: 126px; width: 350px;&quot;&gt; &lt;tbody&gt;  &lt;tr&gt;  &lt;td style =&quot;background-color: #19a7bd ;&quot;&gt;&lt;span style = &quot;color: #ffffff;&quot;&gt;Winery URL&lt;/span&gt;&lt;/td&gt; &lt;td style =&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;http://www.beauxfreres.com/&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style =&quot;background-color: #19a7bd;&quot;&gt;&lt;span style = &quot;color: #ffffff;&quot;&gt;Address&lt;/span&gt;&lt;/td&gt; &lt;td style =&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;15155 NE North Valley Rd, Newberg, OR, 97132, USA&lt;/td&gt; &lt;/tr&gt; &lt;tr&gt; &lt;td style =&quot;background-color: #19a7bd;&quot;&gt;&lt;span style =&quot;color: #ffffff;&quot;&gt;Winery phone&lt;/span&gt;&lt;/td&gt; &lt;td style =&quot;width: 150px;background-color: #f2f0d3 ;&quot;&gt;(503) 537-1137&lt;/td&gt; &lt;/tr&gt; &lt;/tbody&gt; &lt;/table&gt; &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_8532ff6b42c9f445833a29212f9ec035.setContent(html_9848807d3ba9d69318532341f43b85b1);
#
#
#
#         marker_46b8cf33d03e81ebb9e439fb117db0c7.bindPopup(popup_8532ff6b42c9f445833a29212f9ec035)
#         ;
#
#
#
#
#             var marker_550bef8838dc5a27d83ec77434e9a61d = L.marker(
#                 [45.40038819999999, -122.9869325],
#                 {}
#             ).addTo(marker_cluster_aab315a71581cec800147ede2bce15a2);
#
#
#             var icon_6e91773d465d5ff4d58704bc9b2f2cad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;name&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_550bef8838dc5a27d83ec77434e9a61d.setIcon(icon_6e91773d465d5ff4d58704bc9b2f2cad);
#
#
#         var popup_5d633f341ce7ba732673c3b4207c684f = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_a49ee137b6a6521ca18040f2cccc451d = $(`&lt;div id=&quot;html_a49ee137b6a6521ca18040f2cccc451d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt; &lt;html&gt;  &lt;head&gt;  &lt;h4 style = &quot;margin-bottom:10&quot; ; width = &quot;200px&quot;&gt;Ruby Vineyard&lt;/h4&gt;&quot; &lt;/head&gt;     &lt;table style = &quot;height: 126px; width: 350px;&quot;&gt; &lt;tbody&gt;
