# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

table_OVDetail = pd.read_html('file:///Users/darrin/Desktop/Class/Oregon_Wine/vineyard_project/resources/cleaned_google_vineyard_details.html')
table_OVReviews = pd.read_html('file:///Users/darrin/Desktop/Class/Oregon_Wine/vineyard_project/resources/cleaned_google_vineyard_reviews.csv.html')

# %%
print df

# %%
print(f'Total tables: {len(table_OVDetail)}')
# Out:
# Total tables: 1

# %%
df = table_OVDetail[0]
df.head()
#print(df.index)
#print('Row count is:', len(df.index))
# Out:
#    Unnamed: 0 business_status formatted_phone_number                  name  \
# 0         NaN     OPERATIONAL         (509) 526-5230            K Vintners
# 1         NaN     OPERATIONAL         (503) 363-0525         Cória Estates
# 2         NaN     OPERATIONAL         (541) 928-2106  Vivacity Spirits LLC
# 3         NaN     OPERATIONAL         (541) 929-3519        Lumos Wine Co.
# 4         NaN     OPERATIONAL         (503) 679-3497      Gresser Vineyard
#
#                       place_id  rating  user_ratings_total  \
# 0  ChIJb21eb2cVolQRY6JGmq_XmwA     4.4                13.0
# 1  ChIJm-BEGj4GwFQRQz0MEeIFSLM     4.7                80.0
# 2  ChIJ6QmAe3sVwFQR7KVJoo1dw3k     4.9                13.0
# 3  ChIJQeW2X8JIlVQR_36_D7DaRyw     NaN                 NaN
# 4  ChIJPyUzT_0WlVQRPplhbRhoBv8     5.0                 3.0
#
#                                formatted_address  \
# 0  820 Mill Creek Rd, Walla Walla, WA 99362, USA
# 1     8252 Redstone Ave SE, Salem, OR 97306, USA
# 2          140 NE Hill St, Albany, OR 97321, USA
# 3      845 NE 5th St, McMinnville, OR 97128, USA
# 4   37245 SW Nature Dr, Cornelius, OR 97113, USA
#
#                            website      street_address_1  street_address_2  \
# 0        https://houseofsmith.com/     820 Mill Creek Rd               NaN
# 1     http://www.coriaestates.com/  8252 Redstone Ave SE               NaN
# 2  http://www.vivacityspirits.com/        140 NE Hill St               NaN
# 3        http://www.lumoswine.com/         845 NE 5th St               NaN
# 4                              NaN    37245 SW Nature Dr               NaN
#
#           city province  zipcode country_code  \
# 0  Walla Walla       WA    99362          USA
# 1        Salem       OR    97306          USA
# 2       Albany       OR    97321          USA
# 3  McMinnville       OR    97128          USA
# 4    Cornelius       OR    97113          USA
#
#                                                  url location_name
# 0     https://maps.google.com/?cid=43865770597720675           NaN
# 1  https://maps.google.com/?cid=12918581999619030339           NaN
# 2   https://maps.google.com/?cid=8773959361942365676           NaN
# 3   https://maps.google.com/?cid=3190759310728593151           NaN
# 4  https://maps.google.com/?cid=18376489783655504190           NaN

# %%
df = table_OVReviews[0]
df.head()
#print(df.index)
#print('Row count is:', len(df.index))
# Out:
#    Unnamed: 0  Unnamed: 1                 author_name  \
# 0         NaN           0                    Smiledoc
# 1         NaN           1                    Kay Ross
# 2         NaN           2  Linda Teppler (S0rceress0)
# 3         NaN           3              Matias Sanchez
# 4         NaN           4              Michael Hunter
#
#                                           author_url original_language  \
# 0  https://www.google.com/maps/contrib/1063067683...                en
# 1  https://www.google.com/maps/contrib/1123279401...                en
# 2  https://www.google.com/maps/contrib/1049795854...                en
# 3  https://www.google.com/maps/contrib/1034946324...                en
# 4  https://www.google.com/maps/contrib/1134729068...                en
#
#    rating relative_time_description  \
# 0       5               4 years ago
# 1       5                a year ago
# 2       5               3 years ago
# 3       5               4 years ago
# 4       5              3 months ago
#
#                                                 text        time  translated  \
# 0  great wine, great people, great location and f...  1522099905       False
# 1  First time at Coria and not disappointed! Cait...  1628467472       False
# 2  Just tried their Treos Brandy at the Corvallis...  1561834276       False
# 3                  The wine here blows my mind away!  1533678636       False
# 4  New tasting room on 3rd Street in mcminnville....  1659104687       False
#
#                       place_id
# 0  ChIJb21eb2cVolQRY6JGmq_XmwA
# 1  ChIJm-BEGj4GwFQRQz0MEeIFSLM
# 2  ChIJ6QmAe3sVwFQR7KVJoo1dw3k
# 3  ChIJPyUzT_0WlVQRPplhbRhoBv8
# 4  ChIJsQUl8WI4lVQRH7c1h2mlyxs
